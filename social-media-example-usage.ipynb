# %%
import socialmediagraphs as smg
from datetime import datetime

# %%
import importlib
importlib.reload(smg)
# Out:
# <module 'socialmediagraphs' from '/Users/gregor/Library/CloudStorage/OneDrive-SharedLibraries-Onedrive/Documents/W Fall 2024/ICS 311/Assignments/Assignment 6/311 Week 12 Matrix Operations.docx/socialmediagraphs.py'>

# %%
# Define user structure
users = {
    "1": {
        "username": "user1",
        "attributes": {"age": 25, "gender": "male", "location": "NY"},
        "connections": [
            {"type": "follows", "target": "2"},
            {"type": "blocked", "target": "3"}
        ],
        "posts": ["p1", "p2", "p8"],
        "posts_read": ["p5", "p6"],
        "comments": ["c1", "c12", "c11", "c20"]
    },
    "2": {
        "username": "user2",
        "attributes": {"age": 30, "gender": "female", "location": "CA"},
        "connections": [
            {"type": "friends", "target": "1"},
            {"type": "follows", "target": "4"}
        ],
        "posts": ["p3", "p7"],
        "posts_read": ["p7"],
        "comments": ["c2", "c4", "c13", "c19"]  
    },
    "3": {
        "username": "user3",
        "attributes": {"age": 22, "gender": "male", "location": "TX"},
        "connections": [
            {"type": "friends", "target": "5"}
        ],
        "posts": ["p5"],  
        "posts_read": [],
        "comments": ["c5", "c6", "c16"]  
    },
    "4": {
        "username": "user4",
        "attributes": {"age": 27, "gender": "female", "location": "FL"},
        "connections": [
            {"type": "follows", "target": "2"},
            {"type": "has read posts by", "target": "6"}
        ],
        "posts": ["p4"],  
        "posts_read": ["p1", "p2"],
        "comments": ["c3", "c9", "c18", "c14"] 
    },
    "5": {
        "username": "user5",
        "attributes": {"age": 35, "gender": "male", "location": "WA"},
        "connections": [
            {"type": "friends", "target": "3"},
            {"type": "co-worker", "target": "7"}
        ],
        "posts": ["p6"], 
        "posts_read": ["p3", "p4"],
        "comments": ["c7", "c10", "c17", "c8", "c13"]  
    }
}


# Define posts
posts = {
    "p1": {
        "author": "1",
        "content": "Social media analysis is fun!",
        "creation_time": datetime(2024, 11, 18, 10, 0, 0),
        "comments": ["c1", "c12"],
        "viewed_by": ["2", "3", "4", "5"]
    },
    "p2": {
        "author": "1",
        "content": "Python makes it easier!",
        "creation_time": datetime(2024, 11, 18, 12, 0, 0),
        "comments": ["c14"],
        "viewed_by": ["2", "3", "4", "5"]
    },
    "p3": {
        "author": "2",
        "content": "Data science and graphs go hand in hand.",
        "creation_time": datetime(2024, 11, 18, 14, 0, 0),
        "comments": ["c2", "c11", "c19"],
        "viewed_by": ["3", "4", "5"]
    },
    "p4": {
        "author": "4",
        "content": "Analyzing trends is fascinating.",
        "creation_time": datetime(2024, 11, 18, 17, 0, 0),
        "comments": ["c3", "c4"],
        "viewed_by": ["2", "3", "5"]
    },
    "p5": {
        "author": "5",
        "content": "Exploring Python libraries today.",
        "creation_time": datetime(2024, 11, 18, 18, 0, 0),
        "comments": ["c5", "c20"],
        "viewed_by": ["1", "2", "3", "4"]
    },
    "p6": {
        "author": "5",
        "content": "Code, coffee, and focus.",
        "creation_time": datetime(2024, 11, 18, 19, 0, 0),
        "comments": ["c6", "c7"],
        "viewed_by": ["1", "2", "3", "4", "5"]
    },
    "p7": {
        "author": "2",
        "content": "Loving this new framework!",
        "creation_time": datetime(2024, 11, 18, 20, 0, 0),
        "comments": ["c3", "c13"],
        "viewed_by": ["3", "4", "5"]
    },
    "p8": {
        "author": "1",
        "content": "Graphs can represent complex systems.",
        "creation_time": datetime(2024, 11, 18, 21, 0, 0),
        "comments": ["c9", "c10"],
        "viewed_by": ["2", "3", "4", "5"]
    }
}


# Define comments
comments = {
    "c1": {
        "author": "1",
        "post_id": "p1",
        "content": "I totally agree!",
        "creation_time": datetime(2024, 11, 18, 15, 0, 0)
    },
    "c2": {
        "author": "2",
        "post_id": "p7",
        "content": "Great insights!",
        "creation_time": datetime(2024, 11, 18, 16, 0, 0)
    },
    "c3": {
        "author": "4",
        "post_id": "p1",
        "content": "Absolutely true!",
        "creation_time": datetime(2024, 11, 18, 17, 30, 0)
    },
    "c4": {
        "author": "2",
        "post_id": "p3",
        "content": "This post resonates with me.",
        "creation_time": datetime(2024, 11, 18, 17, 45, 0)
    },
    "c5": {
        "author": "3",
        "post_id": "p5",
        "content": "Python is versatile!",
        "creation_time": datetime(2024, 11, 18, 18, 15, 0)
    },
    "c6": {
        "author": "4",
        "post_id": "p6",
        "content": "That’s a great mindset!",
        "creation_time": datetime(2024, 11, 18, 19, 15, 0)
    },
    "c7": {
        "author": "2",
        "post_id": "p6",
        "content": "Agreed, focus is key.",
        "creation_time": datetime(2024, 11, 18, 19, 30, 0)
    },
    "c8": {
        "author": "5",
        "post_id": "p7",
        "content": "Frameworks make life easier.",
        "creation_time": datetime(2024, 11, 18, 20, 15, 0)
    },
    "c9": {
        "author": "4",
        "post_id": "p8",
        "content": "This makes me think about networks!",
        "creation_time": datetime(2024, 11, 18, 21, 15, 0)
    },
    "c10": {
        "author": "5",
        "post_id": "p8",
        "content": "Graphs simplify complex data.",
        "creation_time": datetime(2024, 11, 18, 21, 30, 0)
    },
    "c11": {
        "author": "1",
        "post_id": "p5",
        "content": "Graphs are indeed powerful tools.",
        "creation_time": datetime(2024, 11, 18, 15, 30, 0)
    },
    "c12": {
        "author": "1",
        "post_id": "p1",
        "content": "Social media analysis is an interesting field.",
        "creation_time": datetime(2024, 11, 18, 16, 0, 0)
    },
    "c13": {
        "author": "2",
        "post_id": "p3",
        "content": "I love the way you presented this!",
        "creation_time": datetime(2024, 11, 18, 17, 50, 0)
    },
    "c14": {
        "author": "4",
        "post_id": "p2",
        "content": "Python is the ultimate tool for data analysis.",
        "creation_time": datetime(2024, 11, 18, 18, 0, 0)
    },
    "c20": {
        "author": "1",
        "post_id": "p5",
        "content": "Libraries like Pandas make life so much easier.",
        "creation_time": datetime(2024, 11, 18, 16, 20, 0)
    }
}

# %%
# Example usage
G = smg.build_social_graph(users, posts, comments)
selected_posts = smg.filter_posts_by_graph(
    G, 
    include_keywords=["data", "can"], 
    user_filter={"gender": "male"}
)
if not selected_posts:
    print("No posts matched the filter criteria. Please adjust your filters.")
else:
    smg.generate_word_cloud(selected_posts)

# %%
G = smg.build_social_graph(users, posts, comments)
selected_posts = smg.filter_posts_by_graph(
    G, 
    include_keywords=["data"], 
    user_filter={"gender": "female"}
)
if not selected_posts:
    print("No posts matched the filter criteria. Please adjust your filters.")
else:
    smg.generate_word_cloud(selected_posts)

# %%
# Display graph can be called to simply display the generated graph without considering post importance.

smg.display_graph(G)

# %%
# The second argument is importance criteria: "views", "comments", "mixed"
# The third argument the weight for views if "mixed" is used. Weight is between 0 and 1
# and the weight for comments is 1 - weight.
# The fourth argument is k, the number of the most important posts to display.
# These are displayed in descending order.

smg.display_important_posts(G, "views", .5, 3)

# %%
smg.display_important_posts(G, "comments", .5, 4)

# %%
smg.display_important_posts(G, "mixed", .3, 5)
